# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
data=pd.read_csv("../input/cafe-chatbot-dataset/conversationo.csv")
data.head()

# %%
data.isnull().sum()

# %%
data=data.dropna()

# %%
data.head()

# %%
from nltk.corpus import stopwords
from nltk.stem  import WordNetLemmatizer
from wordcloud import WordCloud,ImageColorGenerator,STOPWORDS
from os import path, getcwd
from PIL import Image
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
import re,string,unicodedata

# %%
# load stop words
stop_word = stopwords.words('english')

# %%
def clean(text):
    text=re.sub(r"#\w+"," ",text)
    text=re.sub(r"@\w+"," ",text)
    text=re.sub(r"\d+"," ",text)
    text=re.sub(r"http\S+"," ",text)
    text=re.sub("r<.*?>"," ",text)
    text=text.split()
    text=" ".join([word for word in text if not word in stop_word])
    return text

# %%
data.head()

# %%
data["Question"]=data["Question"].apply(lambda x:clean(x))
data.head()

# %%
data["answer"]=data["answer"].apply(lambda x:clean(x))
data.head()

# %%
import string
string.punctuation
re_punc = re.compile('[%s]' % re.escape(string.punctuation))
data["Question"]=[re_punc.sub(" ",w) for w in data["Question"]]
data["Question"]

# %%
import string
string.punctuation
re_punc = re.compile('[%s]' % re.escape(string.punctuation))
data["answer"]=[re_punc.sub(" ",w) for w in data["answer"]]
data.head()

# %%
data["answer"]=[word.lower() for word in data["answer"]]
data["answer"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ead76ad0b892> in <module>
# ----> 1 data["answer"]=[word.lower() for word in data["answer"]]
#       2 data["answer"]
#
# NameError: name 'data' is not defined

# %%
data["Question"]=[word.lower() for word in data["Question"]]
data["Question"]

# %%
data.head()

# %%
x=np.array(data["answer"])
x

# %%
y=np.array(data["answer"])
y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
print(cv)

# %%
x_train=cv.fit_transform(x_train)
x_test=cv.transform(x_test)

# %%
x_train.toarray()

# %%
x_test.toarray()

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten,Activation
from keras.utils import to_categorical

# %%
from sklearn.tree import DecisionTreeClassifier
Machine=DecisionTreeClassifier()
Machine.fit(x_train,y_train)

# %%
Prediction=Machine.predict(x_test)
Prediction

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(Prediction,y_test)*100

# %%
Machine.score(x_train,y_train)*100

# %%
data.iloc[45:50]

# %%
a=x_test[1:2]
Machine.predict(a)
